# %% [markdown]
# <a href="https://colab.research.google.com/github/a9garza/python_fundamentals/blob/main/Analisis_y_Visualizaci%C3%B3n_de_Medallas_por_Pa%C3%ADs_y_A%C3%B1o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("athlete_events.csv")
df = df[df["Medal"].notnull()]
medals_country = df["Team"].value_counts()

medals_country = medals_country.head(10)

total_medals = medals_country.sum()

ax = medals_country.plot(kind="bar", color="skyblue")

plt.title(f"Top 10 países con más medallas (Total: {total_medals})")

for i, v in enumerate(medals_country):
    ax.text(i, v + 5, str(v), ha="center", va="center")

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("athlete_events.csv")

ultimo_año = df["Year"].max()

latest = df[df["Year"] == ultimo_año]

medallas_ult_a = latest["Team"].value_counts()

top_10_paises = medallas_ult_a.head(10)
porcentajes = top_10_paises / top_10_paises.sum() * 100
fig, ax = plt.subplots()
ax.pie(top_10_paises, labels=top_10_paises.index, autopct='%1.1f%%', startangle=90)
plt.title(f"Los 10 países con más medallas en el último año: {ultimo_año} (Total: {top_10_paises.sum()})")

plt.show()
